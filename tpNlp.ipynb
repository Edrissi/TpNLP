# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)



# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/nltk-data/nltk_data/corpora/wordnet/data.adj
# /kaggle/input/nltk-data/nltk_data/corpora/wordnet/LICENSE
# /kaggle/input/nltk-data/nltk_data/corpora/wordnet/index.adj
# /kaggle/input/nltk-data/nltk_data/corpora/wordnet/README
# /kaggle/input/nltk-data/nltk_data/corpora/wordnet/verb.exc
# /kaggle/input/nltk-data/nltk_data/corpora/wordnet/index.adv
# /kaggle/input/nltk-data/nltk_data/corpora/wordnet/index.verb
# /kaggle/input/nltk-data/nltk_data/corpora/wordnet/data.verb
# /kaggle/input/nltk-data/nltk_data/corpora/wordnet/lexnames
# /kaggle/input/nltk-data/nltk_data/corpora/wordnet/data.noun
# /kaggle/input/nltk-data/nltk_data/corpora/wordnet/noun.exc
# /kaggle/input/nltk-data/nltk_data/corpora/wordnet/index.noun
# /kaggle/input/nltk-data/nltk_data/corpora/wordnet/adj.exc
# /kaggle/input/nltk-data/nltk_data/corpora/wordnet/index.sense
# /kaggle/input/nltk-data/nltk_data/corpora/wordnet/adv.exc
# /kaggle/input/nltk-data/nltk_data/corpora/wordnet/cntlist.rev
# /kaggle/input/nltk-data/nltk_data/corpora/wordnet/data.adv
# /kaggle/input/nltk-data/nltk_data/corpora/wordnet/citation.bib
# /kaggle/input/nltk-data/nltk_data/corpora/stopwords/arabic
# /kaggle/input/nltk-data/nltk_data/corpora/stopwords/tajik
# /kaggle/input/nltk-data/nltk_data/corpora/stopwords/greek
# /kaggle/input/nltk-data/nltk_data/corpora/stopwords/norwegian
# /kaggle/input/nltk-data/nltk_data/corpora/stopwords/indonesian
# /kaggle/input/nltk-data/nltk_data/corpora/stopwords/english
# /kaggle/input/nltk-data/nltk_data/corpora/stopwords/README
# /kaggle/input/nltk-data/nltk_data/corpora/stopwords/french
# /kaggle/input/nltk-data/nltk_data/corpora/stopwords/kazakh
# /kaggle/input/nltk-data/nltk_data/corpora/stopwords/slovene
# /kaggle/input/nltk-data/nltk_data/corpora/stopwords/russian
# /kaggle/input/nltk-data/nltk_data/corpora/stopwords/danish
# /kaggle/input/nltk-data/nltk_data/corpora/stopwords/turkish
# /kaggle/input/nltk-data/nltk_data/corpora/stopwords/finnish
# /kaggle/input/nltk-data/nltk_data/corpora/stopwords/azerbaijani
# /kaggle/input/nltk-data/nltk_data/corpora/stopwords/romanian
# /kaggle/input/nltk-data/nltk_data/corpora/stopwords/german
# /kaggle/input/nltk-data/nltk_data/corpora/stopwords/swedish
# /kaggle/input/nltk-data/nltk_data/corpora/stopwords/italian
# /kaggle/input/nltk-data/nltk_data/corpora/stopwords/hungarian
# /kaggle/input/nltk-data/nltk_data/corpora/stopwords/dutch
# /kaggle/input/nltk-data/nltk_data/corpora/stopwords/nepali
# /kaggle/input/nltk-data/nltk_data/corpora/stopwords/portuguese
# /kaggle/input/nltk-data/nltk_data/corpora/stopwords/spanish
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/portuguese.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/greek.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/estonian.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/czech.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/danish.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/russian.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/README
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/english.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/italian.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/german.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/polish.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/french.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/norwegian.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/swedish.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/dutch.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/slovene.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/turkish.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/spanish.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/finnish.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/PY3/portuguese.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/PY3/greek.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/PY3/estonian.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/PY3/czech.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/PY3/danish.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/PY3/russian.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/PY3/README
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/PY3/english.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/PY3/italian.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/PY3/german.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/PY3/polish.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/PY3/french.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/PY3/norwegian.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/PY3/swedish.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/PY3/dutch.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/PY3/slovene.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/PY3/turkish.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/PY3/spanish.pickle
# /kaggle/input/nltk-data/nltk_data/tokenizers/punkt/PY3/finnish.pickle
# /kaggle/input/nltk-data/nltk_data/taggers/averaged_perceptron_tagger/averaged_perceptron_tagger.pickle
# /kaggle/input/customer-support-on-twitter/sample.csv
# /kaggle/input/customer-support-on-twitter/twcs/twcs.csv

# %%
# !pip install nltk
import nltk
import string
# Out:
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (3.2.4)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from nltk) (1.16.0)

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import pandas as pd
df = pd.read_csv('/kaggle/input/customer-support-on-twitter/sample.csv')
text_column_name = 'text'

text_list = df[text_column_name].tolist()
print(text_list[0])
print(text_list[1])
print(text_list[3])
# Out:
# @AppleSupport causing the reply to be disregarded and the tapped notification under the keyboard is opened😡😡😡
# @105835 Your business means a lot to us. Please DM your name, zip code and additional details about your concern. ^RR https://t.co/znUu1VJn9r
# @105836 LiveChat is online at the moment - https://t.co/SY94VtU8Kq or contact 03331 031 031 option 1, 4, 3 (Leave a message) to request a call back

# %%
text_list = [text.lower() for text in text_list]
print(text_list[0])
print(text_list[1])
print(text_list[3])
# Out:
# @applesupport causing the reply to be disregarded and the tapped notification under the keyboard is opened😡😡😡
# @105835 your business means a lot to us. please dm your name, zip code and additional details about your concern. ^rr https://t.co/znuu1vjn9r
# @105836 livechat is online at the moment - https://t.co/sy94vtu8kq or contact 03331 031 031 option 1, 4, 3 (leave a message) to request a call back

# %%
tokenized_text = [nltk.tokenize.word_tokenize(text) for text in text_list]
print(tokenized_text[0])
print(tokenized_text[1])
print(tokenized_text[3])
# Out:
# ['@', 'applesupport', 'causing', 'the', 'reply', 'to', 'be', 'disregarded', 'and', 'the', 'tapped', 'notification', 'under', 'the', 'keyboard', 'is', 'opened😡😡😡']
# ['@', '105835', 'your', 'business', 'means', 'a', 'lot', 'to', 'us', '.', 'please', 'dm', 'your', 'name', ',', 'zip', 'code', 'and', 'additional', 'details', 'about', 'your', 'concern', '.', '^rr', 'https', ':', '//t.co/znuu1vjn9r']
# ['@', '105836', 'livechat', 'is', 'online', 'at', 'the', 'moment', '-', 'https', ':', '//t.co/sy94vtu8kq', 'or', 'contact', '03331', '031', '031', 'option', '1', ',', '4', ',', '3', '(', 'leave', 'a', 'message', ')', 'to', 'request', 'a', 'call', 'back']

# %%
cleaned_tokenized_text = [[token for token in text if token not in string.punctuation] for text in tokenized_text]

print(cleaned_tokenized_text[0])
print(cleaned_tokenized_text[1])
print(cleaned_tokenized_text[3])
# Out:
# ['applesupport', 'causing', 'the', 'reply', 'to', 'be', 'disregarded', 'and', 'the', 'tapped', 'notification', 'under', 'the', 'keyboard', 'is', 'opened😡😡😡']
# ['105835', 'your', 'business', 'means', 'a', 'lot', 'to', 'us', 'please', 'dm', 'your', 'name', 'zip', 'code', 'and', 'additional', 'details', 'about', 'your', 'concern', '^rr', 'https', '//t.co/znuu1vjn9r']
# ['105836', 'livechat', 'is', 'online', 'at', 'the', 'moment', 'https', '//t.co/sy94vtu8kq', 'or', 'contact', '03331', '031', '031', 'option', '1', '4', '3', 'leave', 'a', 'message', 'to', 'request', 'a', 'call', 'back']

# %%
cleaned_tokenized_text = [[token for token in text if not token.isnumeric()] for text in cleaned_tokenized_text]
print(cleaned_tokenized_text[0])
print(cleaned_tokenized_text[1])
print(cleaned_tokenized_text[3])
# Out:
# ['applesupport', 'causing', 'the', 'reply', 'to', 'be', 'disregarded', 'and', 'the', 'tapped', 'notification', 'under', 'the', 'keyboard', 'is', 'opened😡😡😡']
# ['your', 'business', 'means', 'a', 'lot', 'to', 'us', 'please', 'dm', 'your', 'name', 'zip', 'code', 'and', 'additional', 'details', 'about', 'your', 'concern', '^rr', 'https', '//t.co/znuu1vjn9r']
# ['livechat', 'is', 'online', 'at', 'the', 'moment', 'https', '//t.co/sy94vtu8kq', 'or', 'contact', 'option', 'leave', 'a', 'message', 'to', 'request', 'a', 'call', 'back']

# %%
from nltk.corpus import stopwords

cleaned_tokenized_text = [[token for token in text if token not in stopwords.words('english')] for text in cleaned_tokenized_text]


print(cleaned_tokenized_text[0])
print(cleaned_tokenized_text[1])
print(cleaned_tokenized_text[3])
# Out:
# ['applesupport', 'causing', 'reply', 'disregarded', 'tapped', 'notification', 'keyboard', 'opened😡😡😡']
# ['business', 'means', 'lot', 'us', 'please', 'dm', 'name', 'zip', 'code', 'additional', 'details', 'concern', '^rr', 'https', '//t.co/znuu1vjn9r']
# ['livechat', 'online', 'moment', 'https', '//t.co/sy94vtu8kq', 'contact', 'option', 'leave', 'message', 'request', 'call', 'back']

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
stemmed_tokenized_text = [[stemmer.stem(token) for token in text] for text in cleaned_tokenized_text]
print(stemmed_tokenized_text[0])
print(stemmed_tokenized_text[1])
print(stemmed_tokenized_text[3])
# Out:
# ['applesupport', 'caus', 'repli', 'disregard', 'tap', 'notif', 'keyboard', 'opened😡😡😡']
# ['busi', 'mean', 'lot', 'us', 'pleas', 'dm', 'name', 'zip', 'code', 'addit', 'detail', 'concern', '^rr', 'http', '//t.co/znuu1vjn9r']
# ['livechat', 'onlin', 'moment', 'http', '//t.co/sy94vtu8kq', 'contact', 'option', 'leav', 'messag', 'request', 'call', 'back']
